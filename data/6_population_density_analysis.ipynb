# %%
import pandas as pd

density_df = pd.read_csv(r'C:\Users\opiej\ufo-analysis-capstone\ufo-analysis-capstone\data\us_city_population_density.csv')

# %%
print(density_df.head())
print(density_df.columns.tolist())
# Out:
#    Index         City        State  Population Density (Persons/Square Mile)  \
# 0      1     New York     New York                                     28211
# 1      2  Los Angeles   California                                      8484
# 2      3      Chicago     Illinois                                     11883
# 3      4      Houston        Texas                                      3842
# 4      5      Phoenix      Arizona                                      3126
#
#    2016 Population  Land Area (Square Miles)
# 0          8537673                       303
# 1          3976322                       469
# 2          2704958                       228
# 3          2303482                       600
# 4          1615017                       517
# ['Index', 'City', 'State', 'Population Density (Persons/Square Mile)', '2016 Population', 'Land Area (Square Miles)']

# %%
density_df.columns = density_df.columns.str.strip().str.lower().str.replace('', '')
print(density_df.columns.tolist())
# Out:
# ['index', 'city', 'state', 'population_density_(persons/square_mile)', '2016_population', 'land_area_(square_miles)']

# %%
density_df.columns = (
    density_df.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_')
    .str.replace('(', '')
    .str.replace(')', '')
    .str.replace('/', '_')
)

# %%
density_df = density_df.rename(columns={
    'population_density_persons_square_mile': 'population_density',
    '2016_population': 'population',
    'land_area_square_miles': 'land_area'
})

# %%
print(density_df[['city', 'state', 'population_density', 'population']].head())
# Out:
#           city        state  population_density  population
# 0     New York     New York               28211     8537673
# 1  Los Angeles   California                8484     3976322
# 2      Chicago     Illinois               11883     2704958
# 3      Houston        Texas                3842     2303482
# 4      Phoenix      Arizona                3126     1615017

# %%
print("Missing:", density_df.isna().sum())
print("Duplicates:", density_df.duplicated().sum())
# Out:
# Missing: index                 0
# city                  0
# state                 0
# population_density    0
# population            0
# land_area             0
# dtype: int64
# Duplicates: 0

# %%
top10 = density_df.sort_values(by='population_density', ascending=False).head(10)
print(top10[['city','state','population_density']])
# Out:
#                 city           state  population_density
# 503       Union City      New Jersey               54138
# 706    West New York      New Jersey               52815
# 694          Hoboken      New Jersey               42484
# 0           New York        New York               28211
# 496          Passaic      New Jersey               22424
# 412       Somerville   Massachusetts               19738
# 634  Huntington Park      California               19561
# 12     San Francisco      California               18581
# 76       Jersey City      New Jersey               17860
# 176         Paterson      New Jersey               17438

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.barplot(x="population_density", y="city", data=top10, hue="state", dodge=False, palette="viridis")
plt.title("Top 10 U.S. Cities by Population Density")
plt.xlabel("People per Sq. Mile")
plt.ylabel("City")
plt.tight_layout()
plt.show()

# %%
# Save to CSV
density_df.to_csv(r'C:\Users\opiej\ufo-analysis-capstone\ufo-analysis-capstone\data\us_city_population_density_clean.csv', index=False)
